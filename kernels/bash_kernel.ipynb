# %% [markdown]
# # BASH Kernel (Demonstration)
# This is a demonstration of a [BASH](https://en.wikipedia.org/wiki/Bash_%28Unix_shell%29) kernel built with the [Callysto](https://github.com/ajmazurie/Callysto) project.
#
# Any text written in the cells of this notebook will be considered a BASH command, and executed correspondingly. Results of the command are printed as they would in a terminal.
#
# *Note: This kernel makes use of the [pexpect](https://pexpect.readthedocs.org/en/stable/) library to handle the communication with a BASH sub-process, similar to the [bash_kernel](https://github.com/takluyver/bash_kernel) kernel provided with Jupyter.*

# %% [markdown]
# ## Local shell
# By default this kernel runs a BASH subprocess and send any user input to it:

# %%
gls -la --color=auto
# Out:
# total 1396
# drwxr-xr-x 15 ajmazurie staff    510 Mar 11 17:03 .
# drwxr-xr-x  9 ajmazurie staff    306 Jun 23 16:04 ..
# -rw-r--r--  1 ajmazurie staff   6148 Feb 29 14:50 .DS_Store
# drwxr-xr-x  3 ajmazurie staff    102 Feb 29 16:18 .ipynb_checkpoints
# drwxr-xr-x  7 ajmazurie staff    238 Jun 23 16:24 bash_kernel
# -rw-r--r--  1 ajmazurie staff  21197 Mar 11 17:03 bash_kernel.ipynb
# -rw-------  1 ajmazurie staff 292971 Feb 26 15:34 bash_kernel.png
# drwxr-xr-x  6 ajmazurie staff    204 Feb 25 13:28 neo4j_kernel
# -rw-r--r--  1 ajmazurie staff  85439 Feb 25 13:46 neo4j_kernel.ipynb
# -rw-------  1 ajmazurie staff 790330 Feb 25 13:37 neo4j_kernel.png
# drwxr-xr-x  6 ajmazurie staff    204 Feb 29 16:42 rdf_kernel
# drwxr-xr-x  6 ajmazurie staff    204 Mar 10 14:24 regex_kernel
# drwxr-xr-x  7 ajmazurie staff    238 Jun 23 15:56 sql_kernel
# -rw-r--r--  1 ajmazurie staff   4641 Feb 25 13:46 sql_kernel.ipynb
# -rw-------  1 ajmazurie staff 215655 Feb 25 13:47 sql_kernel.png

# %% [markdown]
# Here we are attempting to run a command that does not exist, resulting in an error:

# %%
foo
# Out:
# bash: foo: command not found
# Process returned a non-zero exit code: 127

# %%
fortune | cowsay -f stegosaurus | lolcat
# Out:
#  ________________________
# < The future lies ahead. >
#  ------------------------
# \                             .       .
#  \                           / `.   .' "
#   \                  .---.  <    > <    >  .---.
#    \                 |    \  \ - ~ ~ - /  /    |
#          _____          ..-~             ~-..-~
#         |     |   \~~~\.'                    `./~~~/
#        ---------   \__/                        \__/
#       .'  O    \     /               /       \  "
#      (_____,    `._.'               |         }  \/~~~/
#       `----.          /       }     |        /    \__/
#             `-.      |       /      |       /      `. ,~~|
#                 ~-.__|      /_ - ~ ^|      /- _      `..-'
#                      |     /        |     /     ~-.     `-. _  _  _
#                      |_____|        |_____|         ~ - . _ _ _ _ _>

# %% [markdown]
# ## Remote shell
# This kernel has two magic commands, `ssh-login` and `ssh-logout` to log in and out of an SSH server. Once logged in, any command you send will be sent to the server through the SSH channel:

# %%
%ssh-login hyalite.rcg.montana.edu
uname -a
# Out:
# Linux hyalite 2.6.32-431.29.2.el6.x86_64 #1 SMP Tue Sep 9 21:36:05 UTC 2014 x86_64 x86_64 x86_64 GNU/Linux

# %%
%ssh-logout
uname -a
# Out:
# Darwin Pimiento.local 14.5.0 Darwin Kernel Version 14.5.0: Wed Jul 29 02:26:53 PDT 2015; root:xnu-2782.40.9~1/RELEASE_X86_64 x86_64
